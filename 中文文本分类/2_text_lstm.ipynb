# %%
import tensorflow as tf
from tensorflow import logging
from tensorflow import gfile
import os
import numpy as np
import math


logging.set_verbosity(logging.INFO)

# %% [markdown]
# 定义超参数列表

# %%
def get_default_params():
    return tf.contrib.training.HParams(
        num_embedding_size=16,
        num_timesteps=50,
        num_lstm_layers=2,
        num_lstm_nodes=[20, 28],
        num_fc_nodes=19,
        batch_size=100,
        clip_lstm_grads=1.0,
        learning_rate=0.001,
        num_word_threshould=10,
    )


hps = get_default_params()
print(hps.num_lstm_nodes)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# [20, 28]

# %%
# input file
seg_train_file = './cnews/cnews.train.seg.txt'
seg_test_file = './cnews/cnews.test.seg.txt'
seg_val_file = './cnews/cnews.val.seg.txt'

# %%
# 词表文件
vocab_file = './cnews/cnews.vocab.txt'

# %%
# 类别文件
category_file = './cnews/cnews.category.txt'

# %%
output_folder = './cnews/run_text_rnn'
if not gfile.Exists(output_folder):
    gfile.MakeDirs(output_folder)

# %%
class Vocab:
    def __init__(self, filename, num_word_threshould):
        self._word_to_id = {}
        self._num_word_threshould = num_word_threshould  #阈值，少于这个数就不要了
        self._unk_id = -1
        self._read_file(filename)

    def _read_file(self, filename):
        with open(filename, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        for line in lines:
            word, frequency = line.strip('\r\n').split('\t')
            frequency = int(frequency)
            if frequency < self._num_word_threshould:
                continue
            idx = len(self._word_to_id)
            if word == '<UNK>':
                self._unk_id = idx
            self._word_to_id[word] = idx

    def word_to_id(self, word):
        return self._word_to_id.get(word, self._unk_id)

    def sentence_to_id(self, sentence):
        word_ids = [self.word_to_id(cur_word) for cur_word in sentence.split()]
        return word_ids

    def size(self):
        return len(self._word_to_id)

    @property #装饰器，将函数变成一个属性可以调用
    def get_unk_id(self):
        return self._unk_id

# %%
vocab = Vocab(vocab_file, hps.num_word_threshould)
vocab_size = vocab.size()
logging.info('vocab size：%d' % vocab_size) #打印词表的长度
# Out:
# INFO:tensorflow:vocab size：77325

# %% [markdown]
# 测试一下

# %%
test_str = '的 在 你好 是'
logging.info('sentence2id: %s' % vocab.sentence_to_id(test_str))
# Out:
# INFO:tensorflow:sentence2id: [2, 4, 9902, 7]

# %% [markdown]
# 查找类别的编号

# %%
class CategoryDict:
    def __init__(self, filename):
        self._category_to_id = {}
        with open(filename, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        for line in lines:
            category = line.strip('\r\n')
            idx = len(self._category_to_id)
            self._category_to_id[category] = idx

    def category_to_id(self, category_name):
        if not category_name in self._category_to_id:
            raise Exception('%s is not in category list' % category_name)
        return self._category_to_id[category_name]

    def size(self):
        return len(self._category_to_id)

# %%
category_vocab = CategoryDict(category_file)
num_classes = category_vocab.size()

logging.info(num_classes)
logging.info(category_vocab.category_to_id('家居'))
# Out:
# INFO:tensorflow:10
# INFO:tensorflow:2

# %%
class TextDataSet:
    def __init__(self, filename, vocab, category_vocab, num_timesteps):
        self._vocab = vocab
        self._category_vocab = category_vocab
        self._num_timesteps = num_timesteps
        # 矩阵 [batch_size , num_timesteps]
        self._inputs = []
        # vector
        self._outputs = []
        self._indicator = 0
        self._parse_file(filename)

    def _parse_file(self, filename):
        logging.info('Loading data from %s' % filename)
        with open(filename, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        for line in lines:
            label, content = line.strip('\r\n').split('\t')
            id_label = self._category_vocab.category_to_id(label)
            id_words = self._vocab.sentence_to_id(content)
            # id_words 20 60    _num_timesteps:50
            id_words = id_words[0: self._num_timesteps]
            padding_num = self._num_timesteps - len(id_words)
            id_words = id_words + [self._vocab.get_unk_id for i in range(padding_num)]
            self._inputs.append(id_words)
            self._outputs.append(id_label)
        # 列表变成 矩阵形式
        self._inputs = np.asarray(self._inputs, dtype=np.int32)
        self._outputs = np.asarray(self._outputs, dtype=np.int32)
        self._random_shuffle()

    def _random_shuffle(self):
        p = np.random.permutation(len(self._inputs))
        self._inputs = self._inputs[p]
        self._outputs = self._outputs[p]

    def next_batch(self, batch_size):
        end_indicator = self._indicator + batch_size
        if end_indicator > len(self._inputs):
            self._indicator = 0
            self._random_shuffle()
            end_indicator = self._indicator + batch_size
        if end_indicator > len(self._inputs):
            raise Exception('batch size : %d is too large!'% batch_size)
        batch_inputs = self._inputs[self._indicator: end_indicator]
        batch_outputs = self._outputs[self._indicator: end_indicator]
        self._indicator = end_indicator
        return batch_inputs, batch_outputs

# %%
train_dataset = TextDataSet(seg_train_file, vocab, category_vocab, hps.num_timesteps)
test_dataset = TextDataSet(seg_test_file, vocab, category_vocab, hps.num_timesteps)
val_dataset = TextDataSet(seg_val_file, vocab, category_vocab, hps.num_timesteps)

print(train_dataset.next_batch(2))
print(test_dataset.next_batch(2))
print(val_dataset.next_batch(2))
# Out:
# INFO:tensorflow:Loading data from ./cnews/cnews.train.seg.txt
# INFO:tensorflow:Loading data from ./cnews/cnews.test.seg.txt
# INFO:tensorflow:Loading data from ./cnews/cnews.val.seg.txt
# (array([[  468,    11, 58788,  1690, 26736,  1309,  3327,  4663,  1471,
#         15707,     2,  7263,     1, 27873,     2, 48082,     1,  8547,
#         42867,     2, 26468,  8355,     1,  1901, 13393,     2, 10116,
#             1,  3484,  5679,     2,  5379,     1,   453,  9072, 58788,
#         21857,     2,  2201,     3, 17897,  5485,     1,   639,   166,
#           893,  1004,     2,  1505,     1],
#        [  463,   779,  3335,   952,    30,    24,   880,  2218,    44,
#          6007,    77,     0, 28604,  1632, 13135,  1879,   737,   386,
#             2,   265,   245,     1,   311,   181,   350,   463,   779,
#          3335,   952,   649,  1137,    29, 77308,     1,  3220,  2532,
#             6,  2124,  2013,  1274,   747,     1,    40,  2035,   262,
#            28,    22,   603,   880,  1696]]), array([5, 9]))
# (array([[ 1291,  1424,  4851, 11337,  2039,  1195, 11362,  4337,  5197,
#             8,   630,    68,     5,     0,     9,    75,    75,   239,
#           212,    24,     1,  5803,  1645,     4,   222, 25084,  1487,
#            53,  2017,    35,  5628,    11,   424,  1195,  5535, 11337,
#          2039,     2,  1569,  4655,     1, 14343,     8,   980,  5197,
#             9,     5,     8,  5454,  2819],
#        [ 4446, 14603,   685,  1239, 11124,   369,  1632,     8,  2816,
#         51664,   995,  4446,   170,     1,   458,    52,   355,   437,
#           880,   700,     1,  2035, 11753,  2277, 17096,     1,    88,
#         29542,   221,   863, 11798,   786,     1,  4446,  4172,    52,
#           519, 35994,   446,    51,     9,   745,     1,  2360,    69,
#           200,   340,  6121,  2262,  3748]]), array([3, 9]))
# (array([[  325, 11313, 13791, 13848, 69147,  5160, 14331, 16438,   133,
#          1934,    11, 23713, 13848, 69147,   354,  1435,     2,  6049,
#         38901,     3,    43,  4924,     0, 18016,     1,  1259,    85,
#          2635,     2,  5221,    10,  1474,     3,   536,     1,   192,
#         11224,  5025, 69147,    50,  4362,     6,  1883,     0,    91,
#          1453, 11862,   778,     2,   312],
#        [ 1620,    28,   181,    24,  1115, 10743, 10458, 73371,    17,
#             0,    16,   212,   101,   941,   181,   101,  1996,   511,
#           101,   941,   533,   101,  1996,   340,   101,  3395,   497,
#           101,  2652,   596,   101,  3395,   504,   101,     0,   101,
#          2652,   247,   101,  1996,   691,   101,  2652,   754,   101,
#             0,   101,  3395,   727,   101]]), array([8, 4]))

# %% [markdown]
# 构造模型，embedding层后添加LSTM，再添加全连接层，模型使用了dropout正则

# %%
def create_model(hps, vocab_size, num_classes):
    num_timesteps = hps.num_timesteps
    batch_size = hps.batch_size

    inputs = tf.placeholder(dtype=tf.int32, shape=(batch_size, num_timesteps))
    outputs = tf.placeholder(dtype=tf.int32, shape=(batch_size, ))

    keep_prob = tf.placeholder(dtype=tf.float32, name='keep_prob', shape=[]) #正则化的超参数
    # shape = [2, 2]  val: [[0, 0], [0, 0]]
    # shape = [2]  val: [0, 0]
    # shape = [1] val: [0]
    # shape = []  val: 0 标量
    global_step = tf.Variable(initial_value=tf.zeros(shape=[], dtype=tf.int64), name='global_step', trainable=False)

    # embedding 嵌入 编码  机器翻译 nlp
    embedding_initializer = tf.random_uniform_initializer(minval=-1.0, maxval=1.0)
    with tf.variable_scope(name_or_scope='embedding', initializer=embedding_initializer):
        embeddings = tf.get_variable(name='embeddings', shape=[vocab_size, hps.num_embedding_size], dtype=tf.float32, trainable=True)
        # embed_inputs shape : 三维矩阵 shape [batch_size, num_timesteps, num_embedding_size]
        embed_inputs = tf.nn.embedding_lookup(params=embeddings, ids=inputs)
        print('embed_inputs shape:', embed_inputs.shape)


    # lstm
    scale = 1.0 / math.sqrt(hps.num_embedding_size + hps.num_lstm_nodes[-1]) / 3.0
    lstm_initializer = tf.random_uniform_initializer(minval=-scale, maxval=scale)
    with tf.variable_scope(name_or_scope='lstm_nn', initializer=lstm_initializer):
        cells = []
        for i in range(hps.num_lstm_layers):
            cell = tf.nn.rnn_cell.BasicLSTMCell(num_units=hps.num_lstm_nodes[i], state_is_tuple=True, name='lstm_cell')
            cell = tf.nn.rnn_cell.DropoutWrapper(cell, input_keep_prob=keep_prob)
            cells.append(cell)
        cell = tf.nn.rnn_cell.MultiRNNCell(cells, state_is_tuple=True)
        initial_state = cell.zero_state(batch_size=batch_size, dtype=tf.float32)
        # rnn_outputs shape : [batch_size, num_timesteps, hps.num_lstm_nodes[-1]]
        rnn_outputs, middle_hidden_state = tf.nn.dynamic_rnn(cell=cell, inputs=embed_inputs, initial_state=initial_state)
        print('rnn_outputs shape:', rnn_outputs.shape)
        # last shape [batch_size, hps.num_lstm_nodes[-1]]
        last = rnn_outputs[:, -1, :]
        print('last shape: ', last.shape)

    # fc全连接层
    fc_initializer = tf.uniform_unit_scaling_initializer(factor=1.0, dtype=tf.float32)
    with tf.variable_scope(name_or_scope='fc', initializer=fc_initializer):
        fc1 = tf.layers.dense(inputs=last, units=hps.num_fc_nodes, activation=tf.nn.relu, name='fc1')
        fc1_dropout = tf.layers.dropout(fc1, keep_prob)
        logits = tf.layers.dense(fc1_dropout, num_classes, name='fc2')

    # metrics (loss accuracy)
    with tf.name_scope(name='metrics'):
        # sparse_ 用这个：强大一些
        softmax_loss = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=outputs, logits=logits)
        loss = tf.reduce_mean(softmax_loss)
        # argmax [0, 2, 1, 5, 8, 2]  ---> 4
        y_pred = tf.argmax(tf.nn.softmax(logits), axis=1, output_type=tf.int32)
        correct_pred = tf.equal(y_pred, outputs)
        accuracy = tf.reduce_mean(tf.cast(correct_pred, dtype=tf.float32))


    # train_op 训练层
    with tf.name_scope(name='train_op'):
        # train_op = tf.train.AdamOptimizer(hps.learning_rate).minimize(loss, global_step=global_step)
        train_vars = tf.trainable_variables()
        for var in train_vars:
            logging.info('train variable name : %s' % var.name)
        grads, _ = tf.clip_by_global_norm(t_list=tf.gradients(loss, train_vars), clip_norm=hps.clip_lstm_grads)
        # 普通梯度下降 BGD SGD MBGD  动量（有速度） 冲量
        optimizer = tf.train.AdamOptimizer(hps.learning_rate)
        train_op = optimizer.apply_gradients(grads_and_vars=zip(grads, train_vars), global_step=global_step, name='train_op')

    return (
        (inputs, outputs, keep_prob),
        (loss, accuracy),
        (train_op, global_step)
    )

# %%
placeholders, metrics, others = create_model(hps, vocab_size, num_classes)
inputs, outputs, keep_prob = placeholders
loss, accuracy = metrics
train_op, global_step = others
# Out:
# embed_inputs shape: (100, 50, 16)
# WARNING:tensorflow:From <ipython-input-14-a04dea3c40af>:30: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-14-a04dea3c40af>:33: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-14-a04dea3c40af>:36: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From C:\Users\86189\AppData\Local\Continuum\anaconda3\envs\tf1.0\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From C:\Users\86189\AppData\Local\Continuum\anaconda3\envs\tf1.0\lib\site-packages\tensorflow_core\python\ops\rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# rnn_outputs shape: (100, 50, 28)
# last shape:  (100, 28)
# WARNING:tensorflow:From <ipython-input-14-a04dea3c40af>:43: calling UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\86189\AppData\Local\Continuum\anaconda3\envs\tf1.0\lib\site-packages\tensorflow_core\python\util\deprecation.py:507: UniformUnitScaling.__init__ (from tensorflow.python.ops.init_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.initializers.variance_scaling instead with distribution=uniform to get equivalent behavior.
# WARNING:tensorflow:From <ipython-input-14-a04dea3c40af>:45: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From C:\Users\86189\AppData\Local\Continuum\anaconda3\envs\tf1.0\lib\site-packages\tensorflow_core\python\layers\core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-14-a04dea3c40af>:46: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# INFO:tensorflow:train variable name : embedding/embeddings:0
# INFO:tensorflow:train variable name : lstm_nn/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel:0
# INFO:tensorflow:train variable name : lstm_nn/rnn/multi_rnn_cell/cell_0/lstm_cell/bias:0
# INFO:tensorflow:train variable name : lstm_nn/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel:0
# INFO:tensorflow:train variable name : lstm_nn/rnn/multi_rnn_cell/cell_1/lstm_cell/bias:0
# INFO:tensorflow:train variable name : fc/fc1/kernel:0
# INFO:tensorflow:train variable name : fc/fc1/bias:0
# INFO:tensorflow:train variable name : fc/fc2/kernel:0
# INFO:tensorflow:train variable name : fc/fc2/bias:0
# WARNING:tensorflow:From C:\Users\86189\AppData\Local\Continuum\anaconda3\envs\tf1.0\lib\site-packages\tensorflow_core\python\ops\clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# 执行训练模型代码
init_op = tf.global_variables_initializer()
train_keep_prob = 0.8
test_keep_prob = 1.0

num_train_steps = 10000 #训练一万次

# %%
with tf.Session() as sess:
    sess.run(init_op)

    for i in range(num_train_steps):
        batch_inputs, batch_labels = train_dataset.next_batch(hps.batch_size)
        outputs_val = sess.run(fetches=[loss, accuracy, train_op, global_step], feed_dict={
            inputs: batch_inputs,
            outputs: batch_labels,
            keep_prob: train_keep_prob
        })

        loss_val, accuracy_val, _, global_step_val = outputs_val

        if global_step_val % 20 == 0:
            logging.info('Step: %5d, loss: %3.3f, accuracy: %3.5f' % (global_step_val, loss_val, accuracy_val))
        if global_step_val % 200 == 0:
            # 每隔200步 就去测试一下
            # test_dataset.next_batch()
            pass
# Out:
# INFO:tensorflow:Step:     0, loss: 2.302, accuracy: 0.10000
# INFO:tensorflow:Step:    20, loss: 2.302, accuracy: 0.08000
# INFO:tensorflow:Step:    40, loss: 2.257, accuracy: 0.16000
# INFO:tensorflow:Step:    60, loss: 2.295, accuracy: 0.13000
# INFO:tensorflow:Step:    80, loss: 2.272, accuracy: 0.15000
# INFO:tensorflow:Step:   100, loss: 2.247, accuracy: 0.11000
# INFO:tensorflow:Step:   120, loss: 2.160, accuracy: 0.14000
# INFO:tensorflow:Step:   140, loss: 2.087, accuracy: 0.23000
# INFO:tensorflow:Step:   160, loss: 2.011, accuracy: 0.25000
# INFO:tensorflow:Step:   180, loss: 1.980, accuracy: 0.27000
# INFO:tensorflow:Step:   200, loss: 1.826, accuracy: 0.43000
# INFO:tensorflow:Step:   220, loss: 1.743, accuracy: 0.33000
# INFO:tensorflow:Step:   240, loss: 1.656, accuracy: 0.40000
# INFO:tensorflow:Step:   260, loss: 1.730, accuracy: 0.36000
# INFO:tensorflow:Step:   280, loss: 1.703, accuracy: 0.32000
# INFO:tensorflow:Step:   300, loss: 1.718, accuracy: 0.33000
# INFO:tensorflow:Step:   320, loss: 1.649, accuracy: 0.41000
# INFO:tensorflow:Step:   340, loss: 1.614, accuracy: 0.32000
# INFO:tensorflow:Step:   360, loss: 1.759, accuracy: 0.30000
# INFO:tensorflow:Step:   380, loss: 1.568, accuracy: 0.40000
# INFO:tensorflow:Step:   400, loss: 1.537, accuracy: 0.50000
# INFO:tensorflow:Step:   420, loss: 1.480, accuracy: 0.45000
# INFO:tensorflow:Step:   440, loss: 1.499, accuracy: 0.39000
# INFO:tensorflow:Step:   460, loss: 1.663, accuracy: 0.33000
# INFO:tensorflow:Step:   480, loss: 1.352, accuracy: 0.44000
# INFO:tensorflow:Step:   500, loss: 1.321, accuracy: 0.39000
# INFO:tensorflow:Step:   520, loss: 1.495, accuracy: 0.44000
# INFO:tensorflow:Step:   540, loss: 1.350, accuracy: 0.39000
# INFO:tensorflow:Step:   560, loss: 1.425, accuracy: 0.41000
# INFO:tensorflow:Step:   580, loss: 1.437, accuracy: 0.45000
# INFO:tensorflow:Step:   600, loss: 1.242, accuracy: 0.57000
# INFO:tensorflow:Step:   620, loss: 1.380, accuracy: 0.47000
# INFO:tensorflow:Step:   640, loss: 1.442, accuracy: 0.46000
# INFO:tensorflow:Step:   660, loss: 1.245, accuracy: 0.53000
# INFO:tensorflow:Step:   680, loss: 1.260, accuracy: 0.49000
# INFO:tensorflow:Step:   700, loss: 1.291, accuracy: 0.61000
# INFO:tensorflow:Step:   720, loss: 1.292, accuracy: 0.50000
# INFO:tensorflow:Step:   740, loss: 1.239, accuracy: 0.59000
# INFO:tensorflow:Step:   760, loss: 1.221, accuracy: 0.54000
# INFO:tensorflow:Step:   780, loss: 1.204, accuracy: 0.53000
# INFO:tensorflow:Step:   800, loss: 1.207, accuracy: 0.57000
# INFO:tensorflow:Step:   820, loss: 1.081, accuracy: 0.58000
# INFO:tensorflow:Step:   840, loss: 1.330, accuracy: 0.54000
# INFO:tensorflow:Step:   860, loss: 1.356, accuracy: 0.49000
# INFO:tensorflow:Step:   880, loss: 1.301, accuracy: 0.51000
# INFO:tensorflow:Step:   900, loss: 1.136, accuracy: 0.57000
# INFO:tensorflow:Step:   920, loss: 1.189, accuracy: 0.54000
# INFO:tensorflow:Step:   940, loss: 1.112, accuracy: 0.59000
# INFO:tensorflow:Step:   960, loss: 1.345, accuracy: 0.51000
# INFO:tensorflow:Step:   980, loss: 1.234, accuracy: 0.53000
# INFO:tensorflow:Step:  1000, loss: 1.245, accuracy: 0.56000
# INFO:tensorflow:Step:  1020, loss: 1.001, accuracy: 0.64000
# INFO:tensorflow:Step:  1040, loss: 0.970, accuracy: 0.66000
# INFO:tensorflow:Step:  1060, loss: 1.005, accuracy: 0.64000
# INFO:tensorflow:Step:  1080, loss: 1.000, accuracy: 0.64000
# INFO:tensorflow:Step:  1100, loss: 1.114, accuracy: 0.52000
# INFO:tensorflow:Step:  1120, loss: 0.949, accuracy: 0.66000
# INFO:tensorflow:Step:  1140, loss: 1.015, accuracy: 0.67000
# INFO:tensorflow:Step:  1160, loss: 1.113, accuracy: 0.60000
# INFO:tensorflow:Step:  1180, loss: 0.905, accuracy: 0.65000
# INFO:tensorflow:Step:  1200, loss: 0.803, accuracy: 0.69000
# INFO:tensorflow:Step:  1220, loss: 0.919, accuracy: 0.73000
# INFO:tensorflow:Step:  1240, loss: 1.091, accuracy: 0.62000
# INFO:tensorflow:Step:  1260, loss: 0.909, accuracy: 0.68000
# INFO:tensorflow:Step:  1280, loss: 1.021, accuracy: 0.68000
# INFO:tensorflow:Step:  1300, loss: 1.071, accuracy: 0.62000
# INFO:tensorflow:Step:  1320, loss: 0.892, accuracy: 0.69000
# INFO:tensorflow:Step:  1340, loss: 1.015, accuracy: 0.55000
# INFO:tensorflow:Step:  1360, loss: 0.954, accuracy: 0.65000
# INFO:tensorflow:Step:  1380, loss: 1.067, accuracy: 0.63000
# INFO:tensorflow:Step:  1400, loss: 0.997, accuracy: 0.65000
# INFO:tensorflow:Step:  1420, loss: 0.969, accuracy: 0.58000
# INFO:tensorflow:Step:  1440, loss: 1.063, accuracy: 0.61000
# INFO:tensorflow:Step:  1460, loss: 0.838, accuracy: 0.67000
# INFO:tensorflow:Step:  1480, loss: 0.960, accuracy: 0.64000
# INFO:tensorflow:Step:  1500, loss: 0.662, accuracy: 0.79000
# INFO:tensorflow:Step:  1520, loss: 0.821, accuracy: 0.73000
# INFO:tensorflow:Step:  1540, loss: 0.805, accuracy: 0.72000
# INFO:tensorflow:Step:  1560, loss: 0.804, accuracy: 0.72000
# INFO:tensorflow:Step:  1580, loss: 0.768, accuracy: 0.70000
# INFO:tensorflow:Step:  1600, loss: 0.795, accuracy: 0.70000
# INFO:tensorflow:Step:  1620, loss: 0.815, accuracy: 0.72000
# INFO:tensorflow:Step:  1640, loss: 0.731, accuracy: 0.75000
# INFO:tensorflow:Step:  1660, loss: 0.729, accuracy: 0.76000
# INFO:tensorflow:Step:  1680, loss: 0.783, accuracy: 0.76000
# INFO:tensorflow:Step:  1700, loss: 0.717, accuracy: 0.77000
# INFO:tensorflow:Step:  1720, loss: 0.864, accuracy: 0.72000
# INFO:tensorflow:Step:  1740, loss: 0.716, accuracy: 0.77000
# INFO:tensorflow:Step:  1760, loss: 0.966, accuracy: 0.69000
# INFO:tensorflow:Step:  1780, loss: 0.619, accuracy: 0.76000
# INFO:tensorflow:Step:  1800, loss: 0.756, accuracy: 0.72000
# INFO:tensorflow:Step:  1820, loss: 0.670, accuracy: 0.80000
# INFO:tensorflow:Step:  1840, loss: 0.746, accuracy: 0.73000
# INFO:tensorflow:Step:  1860, loss: 0.713, accuracy: 0.75000
# INFO:tensorflow:Step:  1880, loss: 0.624, accuracy: 0.78000
# INFO:tensorflow:Step:  1900, loss: 1.063, accuracy: 0.65000
# INFO:tensorflow:Step:  1920, loss: 0.867, accuracy: 0.66000
# INFO:tensorflow:Step:  1940, loss: 0.817, accuracy: 0.71000
# INFO:tensorflow:Step:  1960, loss: 0.837, accuracy: 0.75000
# INFO:tensorflow:Step:  1980, loss: 0.749, accuracy: 0.78000
# INFO:tensorflow:Step:  2000, loss: 0.656, accuracy: 0.79000
# INFO:tensorflow:Step:  2020, loss: 0.700, accuracy: 0.70000
# INFO:tensorflow:Step:  2040, loss: 0.522, accuracy: 0.82000
# INFO:tensorflow:Step:  2060, loss: 0.594, accuracy: 0.81000
# INFO:tensorflow:Step:  2080, loss: 0.647, accuracy: 0.77000
# INFO:tensorflow:Step:  2100, loss: 0.472, accuracy: 0.83000
# INFO:tensorflow:Step:  2120, loss: 0.633, accuracy: 0.81000
# INFO:tensorflow:Step:  2140, loss: 0.783, accuracy: 0.72000
# INFO:tensorflow:Step:  2160, loss: 0.724, accuracy: 0.74000
# INFO:tensorflow:Step:  2180, loss: 0.615, accuracy: 0.76000
# INFO:tensorflow:Step:  2200, loss: 0.607, accuracy: 0.83000
# INFO:tensorflow:Step:  2220, loss: 0.509, accuracy: 0.85000
# INFO:tensorflow:Step:  2240, loss: 0.703, accuracy: 0.76000
# INFO:tensorflow:Step:  2260, loss: 0.646, accuracy: 0.80000
# INFO:tensorflow:Step:  2280, loss: 0.576, accuracy: 0.81000
# INFO:tensorflow:Step:  2300, loss: 0.591, accuracy: 0.83000
# INFO:tensorflow:Step:  2320, loss: 0.587, accuracy: 0.81000
# INFO:tensorflow:Step:  2340, loss: 0.607, accuracy: 0.80000
# INFO:tensorflow:Step:  2360, loss: 0.666, accuracy: 0.80000
# INFO:tensorflow:Step:  2380, loss: 0.727, accuracy: 0.79000
# INFO:tensorflow:Step:  2400, loss: 0.514, accuracy: 0.82000
# INFO:tensorflow:Step:  2420, loss: 0.572, accuracy: 0.79000
# INFO:tensorflow:Step:  2440, loss: 0.490, accuracy: 0.84000
# INFO:tensorflow:Step:  2460, loss: 0.593, accuracy: 0.82000
# INFO:tensorflow:Step:  2480, loss: 0.536, accuracy: 0.83000
# INFO:tensorflow:Step:  2500, loss: 0.583, accuracy: 0.78000
# INFO:tensorflow:Step:  2520, loss: 0.850, accuracy: 0.77000
# INFO:tensorflow:Step:  2540, loss: 0.480, accuracy: 0.86000
# INFO:tensorflow:Step:  2560, loss: 0.501, accuracy: 0.87000
# INFO:tensorflow:Step:  2580, loss: 0.510, accuracy: 0.85000
# INFO:tensorflow:Step:  2600, loss: 0.504, accuracy: 0.83000
# INFO:tensorflow:Step:  2620, loss: 0.526, accuracy: 0.86000
# INFO:tensorflow:Step:  2640, loss: 0.473, accuracy: 0.85000
# INFO:tensorflow:Step:  2660, loss: 0.613, accuracy: 0.83000
# INFO:tensorflow:Step:  2680, loss: 0.513, accuracy: 0.85000
# INFO:tensorflow:Step:  2700, loss: 0.504, accuracy: 0.86000
# INFO:tensorflow:Step:  2720, loss: 0.523, accuracy: 0.87000
# INFO:tensorflow:Step:  2740, loss: 0.652, accuracy: 0.84000
# INFO:tensorflow:Step:  2760, loss: 0.590, accuracy: 0.82000
# INFO:tensorflow:Step:  2780, loss: 0.470, accuracy: 0.81000
# INFO:tensorflow:Step:  2800, loss: 0.350, accuracy: 0.89000
# INFO:tensorflow:Step:  2820, loss: 0.478, accuracy: 0.87000
# INFO:tensorflow:Step:  2840, loss: 0.503, accuracy: 0.87000
# INFO:tensorflow:Step:  2860, loss: 0.465, accuracy: 0.86000
# INFO:tensorflow:Step:  2880, loss: 0.245, accuracy: 0.92000
# INFO:tensorflow:Step:  2900, loss: 0.578, accuracy: 0.81000
# INFO:tensorflow:Step:  2920, loss: 0.504, accuracy: 0.85000
# INFO:tensorflow:Step:  2940, loss: 0.370, accuracy: 0.89000
# INFO:tensorflow:Step:  2960, loss: 0.439, accuracy: 0.85000
# INFO:tensorflow:Step:  2980, loss: 0.449, accuracy: 0.85000
# INFO:tensorflow:Step:  3000, loss: 0.446, accuracy: 0.87000
# INFO:tensorflow:Step:  3020, loss: 0.534, accuracy: 0.83000
# INFO:tensorflow:Step:  3040, loss: 0.406, accuracy: 0.89000
# INFO:tensorflow:Step:  3060, loss: 0.428, accuracy: 0.83000
# INFO:tensorflow:Step:  3080, loss: 0.466, accuracy: 0.87000
# INFO:tensorflow:Step:  3100, loss: 0.459, accuracy: 0.84000
# INFO:tensorflow:Step:  3120, loss: 0.343, accuracy: 0.87000
# INFO:tensorflow:Step:  3140, loss: 0.322, accuracy: 0.91000
# INFO:tensorflow:Step:  3160, loss: 0.224, accuracy: 0.90000
# INFO:tensorflow:Step:  3180, loss: 0.375, accuracy: 0.90000
# INFO:tensorflow:Step:  3200, loss: 0.386, accuracy: 0.91000
# INFO:tensorflow:Step:  3220, loss: 0.220, accuracy: 0.96000
# INFO:tensorflow:Step:  3240, loss: 0.331, accuracy: 0.89000
# INFO:tensorflow:Step:  3260, loss: 0.408, accuracy: 0.88000
# INFO:tensorflow:Step:  3280, loss: 0.347, accuracy: 0.91000
# INFO:tensorflow:Step:  3300, loss: 0.307, accuracy: 0.88000
# INFO:tensorflow:Step:  3320, loss: 0.312, accuracy: 0.91000
# INFO:tensorflow:Step:  3340, loss: 0.459, accuracy: 0.89000
# INFO:tensorflow:Step:  3360, loss: 0.366, accuracy: 0.90000
# INFO:tensorflow:Step:  3380, loss: 0.335, accuracy: 0.88000
# INFO:tensorflow:Step:  3400, loss: 0.549, accuracy: 0.81000
# INFO:tensorflow:Step:  3420, loss: 0.438, accuracy: 0.89000
# INFO:tensorflow:Step:  3440, loss: 0.379, accuracy: 0.88000
# INFO:tensorflow:Step:  3460, loss: 0.350, accuracy: 0.91000
# INFO:tensorflow:Step:  3480, loss: 0.432, accuracy: 0.89000
# INFO:tensorflow:Step:  3500, loss: 0.355, accuracy: 0.90000
# INFO:tensorflow:Step:  3520, loss: 0.244, accuracy: 0.92000
# INFO:tensorflow:Step:  3540, loss: 0.480, accuracy: 0.83000
# INFO:tensorflow:Step:  3560, loss: 0.324, accuracy: 0.91000
# INFO:tensorflow:Step:  3580, loss: 0.269, accuracy: 0.90000
# INFO:tensorflow:Step:  3600, loss: 0.254, accuracy: 0.90000
# INFO:tensorflow:Step:  3620, loss: 0.243, accuracy: 0.93000
# INFO:tensorflow:Step:  3640, loss: 0.195, accuracy: 0.94000
# INFO:tensorflow:Step:  3660, loss: 0.294, accuracy: 0.93000
# INFO:tensorflow:Step:  3680, loss: 0.473, accuracy: 0.87000
# INFO:tensorflow:Step:  3700, loss: 0.162, accuracy: 0.95000
# INFO:tensorflow:Step:  3720, loss: 0.288, accuracy: 0.94000
# INFO:tensorflow:Step:  3740, loss: 0.296, accuracy: 0.92000
# INFO:tensorflow:Step:  3760, loss: 0.208, accuracy: 0.93000
# INFO:tensorflow:Step:  3780, loss: 0.573, accuracy: 0.82000
# INFO:tensorflow:Step:  3800, loss: 0.285, accuracy: 0.91000
# INFO:tensorflow:Step:  3820, loss: 0.379, accuracy: 0.88000
# INFO:tensorflow:Step:  3840, loss: 0.229, accuracy: 0.93000
# INFO:tensorflow:Step:  3860, loss: 0.284, accuracy: 0.91000
# INFO:tensorflow:Step:  3880, loss: 0.462, accuracy: 0.85000
# INFO:tensorflow:Step:  3900, loss: 0.266, accuracy: 0.95000
# INFO:tensorflow:Step:  3920, loss: 0.347, accuracy: 0.88000
# INFO:tensorflow:Step:  3940, loss: 0.304, accuracy: 0.93000
# INFO:tensorflow:Step:  3960, loss: 0.225, accuracy: 0.94000
# INFO:tensorflow:Step:  3980, loss: 0.119, accuracy: 0.96000
# INFO:tensorflow:Step:  4000, loss: 0.397, accuracy: 0.87000
# INFO:tensorflow:Step:  4020, loss: 0.133, accuracy: 0.95000
# INFO:tensorflow:Step:  4040, loss: 0.257, accuracy: 0.92000
# INFO:tensorflow:Step:  4060, loss: 0.420, accuracy: 0.88000
# INFO:tensorflow:Step:  4080, loss: 0.185, accuracy: 0.96000
# INFO:tensorflow:Step:  4100, loss: 0.371, accuracy: 0.88000
# INFO:tensorflow:Step:  4120, loss: 0.343, accuracy: 0.87000
# INFO:tensorflow:Step:  4140, loss: 0.173, accuracy: 0.93000
# INFO:tensorflow:Step:  4160, loss: 0.314, accuracy: 0.93000
# INFO:tensorflow:Step:  4180, loss: 0.185, accuracy: 0.95000
# INFO:tensorflow:Step:  4200, loss: 0.177, accuracy: 0.96000
# INFO:tensorflow:Step:  4220, loss: 0.264, accuracy: 0.94000
# INFO:tensorflow:Step:  4240, loss: 0.304, accuracy: 0.90000
# INFO:tensorflow:Step:  4260, loss: 0.219, accuracy: 0.93000
# INFO:tensorflow:Step:  4280, loss: 0.252, accuracy: 0.93000
# INFO:tensorflow:Step:  4300, loss: 0.275, accuracy: 0.92000
# INFO:tensorflow:Step:  4320, loss: 0.250, accuracy: 0.88000
# INFO:tensorflow:Step:  4340, loss: 0.173, accuracy: 0.97000
# INFO:tensorflow:Step:  4360, loss: 0.149, accuracy: 0.95000
# INFO:tensorflow:Step:  4380, loss: 0.215, accuracy: 0.93000
# INFO:tensorflow:Step:  4400, loss: 0.337, accuracy: 0.90000
# INFO:tensorflow:Step:  4420, loss: 0.335, accuracy: 0.89000
# INFO:tensorflow:Step:  4440, loss: 0.303, accuracy: 0.92000
# INFO:tensorflow:Step:  4460, loss: 0.247, accuracy: 0.93000
# INFO:tensorflow:Step:  4480, loss: 0.227, accuracy: 0.92000
# INFO:tensorflow:Step:  4500, loss: 0.291, accuracy: 0.92000
# INFO:tensorflow:Step:  4520, loss: 0.197, accuracy: 0.96000
# INFO:tensorflow:Step:  4540, loss: 0.290, accuracy: 0.91000
# INFO:tensorflow:Step:  4560, loss: 0.185, accuracy: 0.93000
# INFO:tensorflow:Step:  4580, loss: 0.134, accuracy: 0.96000
# INFO:tensorflow:Step:  4600, loss: 0.147, accuracy: 0.94000
# INFO:tensorflow:Step:  4620, loss: 0.282, accuracy: 0.89000
# INFO:tensorflow:Step:  4640, loss: 0.258, accuracy: 0.92000
# INFO:tensorflow:Step:  4660, loss: 0.271, accuracy: 0.90000
# INFO:tensorflow:Step:  4680, loss: 0.459, accuracy: 0.90000
# INFO:tensorflow:Step:  4700, loss: 0.191, accuracy: 0.93000
# INFO:tensorflow:Step:  4720, loss: 0.157, accuracy: 0.96000
# INFO:tensorflow:Step:  4740, loss: 0.248, accuracy: 0.94000
# INFO:tensorflow:Step:  4760, loss: 0.292, accuracy: 0.93000
# INFO:tensorflow:Step:  4780, loss: 0.213, accuracy: 0.93000
# INFO:tensorflow:Step:  4800, loss: 0.248, accuracy: 0.93000
# INFO:tensorflow:Step:  4820, loss: 0.277, accuracy: 0.89000
# INFO:tensorflow:Step:  4840, loss: 0.242, accuracy: 0.90000
# INFO:tensorflow:Step:  4860, loss: 0.234, accuracy: 0.93000
# INFO:tensorflow:Step:  4880, loss: 0.343, accuracy: 0.92000
# INFO:tensorflow:Step:  4900, loss: 0.268, accuracy: 0.91000
# INFO:tensorflow:Step:  4920, loss: 0.242, accuracy: 0.93000
# INFO:tensorflow:Step:  4940, loss: 0.301, accuracy: 0.88000
# INFO:tensorflow:Step:  4960, loss: 0.264, accuracy: 0.93000
# INFO:tensorflow:Step:  4980, loss: 0.083, accuracy: 0.97000
# INFO:tensorflow:Step:  5000, loss: 0.118, accuracy: 0.96000
# INFO:tensorflow:Step:  5020, loss: 0.150, accuracy: 0.96000
# INFO:tensorflow:Step:  5040, loss: 0.120, accuracy: 0.96000
# INFO:tensorflow:Step:  5060, loss: 0.185, accuracy: 0.96000
# INFO:tensorflow:Step:  5080, loss: 0.347, accuracy: 0.90000
# INFO:tensorflow:Step:  5100, loss: 0.256, accuracy: 0.93000
# INFO:tensorflow:Step:  5120, loss: 0.360, accuracy: 0.92000
# INFO:tensorflow:Step:  5140, loss: 0.222, accuracy: 0.92000
# INFO:tensorflow:Step:  5160, loss: 0.097, accuracy: 0.98000
# INFO:tensorflow:Step:  5180, loss: 0.095, accuracy: 0.97000
# INFO:tensorflow:Step:  5200, loss: 0.170, accuracy: 0.94000
# INFO:tensorflow:Step:  5220, loss: 0.237, accuracy: 0.94000
# INFO:tensorflow:Step:  5240, loss: 0.067, accuracy: 0.98000
# INFO:tensorflow:Step:  5260, loss: 0.134, accuracy: 0.97000
# INFO:tensorflow:Step:  5280, loss: 0.126, accuracy: 0.97000
# INFO:tensorflow:Step:  5300, loss: 0.126, accuracy: 0.95000
# INFO:tensorflow:Step:  5320, loss: 0.189, accuracy: 0.95000
# INFO:tensorflow:Step:  5340, loss: 0.149, accuracy: 0.96000
# INFO:tensorflow:Step:  5360, loss: 0.198, accuracy: 0.95000
# INFO:tensorflow:Step:  5380, loss: 0.317, accuracy: 0.90000
# INFO:tensorflow:Step:  5400, loss: 0.185, accuracy: 0.94000
# INFO:tensorflow:Step:  5420, loss: 0.074, accuracy: 0.98000
# INFO:tensorflow:Step:  5440, loss: 0.144, accuracy: 0.97000
# INFO:tensorflow:Step:  5460, loss: 0.095, accuracy: 0.97000
# INFO:tensorflow:Step:  5480, loss: 0.071, accuracy: 0.98000
# INFO:tensorflow:Step:  5500, loss: 0.201, accuracy: 0.93000
# INFO:tensorflow:Step:  5520, loss: 0.071, accuracy: 0.98000
# INFO:tensorflow:Step:  5540, loss: 0.157, accuracy: 0.94000
# INFO:tensorflow:Step:  5560, loss: 0.136, accuracy: 0.96000
# INFO:tensorflow:Step:  5580, loss: 0.193, accuracy: 0.94000
# INFO:tensorflow:Step:  5600, loss: 0.130, accuracy: 0.96000
# INFO:tensorflow:Step:  5620, loss: 0.246, accuracy: 0.90000
# INFO:tensorflow:Step:  5640, loss: 0.147, accuracy: 0.95000
# INFO:tensorflow:Step:  5660, loss: 0.147, accuracy: 0.96000
# INFO:tensorflow:Step:  5680, loss: 0.121, accuracy: 0.98000
# INFO:tensorflow:Step:  5700, loss: 0.068, accuracy: 0.97000
# INFO:tensorflow:Step:  5720, loss: 0.067, accuracy: 0.97000
# INFO:tensorflow:Step:  5740, loss: 0.139, accuracy: 0.95000
# INFO:tensorflow:Step:  5760, loss: 0.149, accuracy: 0.94000
# INFO:tensorflow:Step:  5780, loss: 0.238, accuracy: 0.94000
# INFO:tensorflow:Step:  5800, loss: 0.032, accuracy: 0.99000
# INFO:tensorflow:Step:  5820, loss: 0.113, accuracy: 0.95000
# INFO:tensorflow:Step:  5840, loss: 0.398, accuracy: 0.90000
# INFO:tensorflow:Step:  5860, loss: 0.157, accuracy: 0.94000
# INFO:tensorflow:Step:  5880, loss: 0.189, accuracy: 0.95000
# INFO:tensorflow:Step:  5900, loss: 0.179, accuracy: 0.95000
# INFO:tensorflow:Step:  5920, loss: 0.052, accuracy: 0.98000
# INFO:tensorflow:Step:  5940, loss: 0.203, accuracy: 0.93000
# INFO:tensorflow:Step:  5960, loss: 0.264, accuracy: 0.92000
# INFO:tensorflow:Step:  5980, loss: 0.117, accuracy: 0.96000
# INFO:tensorflow:Step:  6000, loss: 0.173, accuracy: 0.96000
# INFO:tensorflow:Step:  6020, loss: 0.161, accuracy: 0.96000
# INFO:tensorflow:Step:  6040, loss: 0.060, accuracy: 0.98000
# INFO:tensorflow:Step:  6060, loss: 0.181, accuracy: 0.95000
# INFO:tensorflow:Step:  6080, loss: 0.134, accuracy: 0.96000
# INFO:tensorflow:Step:  6100, loss: 0.177, accuracy: 0.95000
# INFO:tensorflow:Step:  6120, loss: 0.127, accuracy: 0.98000
# INFO:tensorflow:Step:  6140, loss: 0.103, accuracy: 0.98000
# INFO:tensorflow:Step:  6160, loss: 0.117, accuracy: 0.96000
# INFO:tensorflow:Step:  6180, loss: 0.069, accuracy: 0.97000
# INFO:tensorflow:Step:  6200, loss: 0.134, accuracy: 0.98000
# INFO:tensorflow:Step:  6220, loss: 0.162, accuracy: 0.97000
# INFO:tensorflow:Step:  6240, loss: 0.079, accuracy: 0.97000
# INFO:tensorflow:Step:  6260, loss: 0.222, accuracy: 0.94000
# INFO:tensorflow:Step:  6280, loss: 0.115, accuracy: 0.95000
# INFO:tensorflow:Step:  6300, loss: 0.251, accuracy: 0.94000
# INFO:tensorflow:Step:  6320, loss: 0.242, accuracy: 0.94000
# INFO:tensorflow:Step:  6340, loss: 0.172, accuracy: 0.94000
# INFO:tensorflow:Step:  6360, loss: 0.154, accuracy: 0.95000
# INFO:tensorflow:Step:  6380, loss: 0.162, accuracy: 0.95000
# INFO:tensorflow:Step:  6400, loss: 0.112, accuracy: 0.96000
# INFO:tensorflow:Step:  6420, loss: 0.045, accuracy: 0.99000
# INFO:tensorflow:Step:  6440, loss: 0.157, accuracy: 0.96000
# INFO:tensorflow:Step:  6460, loss: 0.167, accuracy: 0.96000
# INFO:tensorflow:Step:  6480, loss: 0.178, accuracy: 0.95000
# INFO:tensorflow:Step:  6500, loss: 0.042, accuracy: 0.99000
# INFO:tensorflow:Step:  6520, loss: 0.079, accuracy: 0.97000
# INFO:tensorflow:Step:  6540, loss: 0.091, accuracy: 0.96000
# INFO:tensorflow:Step:  6560, loss: 0.126, accuracy: 0.94000
# INFO:tensorflow:Step:  6580, loss: 0.085, accuracy: 0.98000
# INFO:tensorflow:Step:  6600, loss: 0.124, accuracy: 0.98000
# INFO:tensorflow:Step:  6620, loss: 0.091, accuracy: 0.95000
# INFO:tensorflow:Step:  6640, loss: 0.074, accuracy: 0.98000
# INFO:tensorflow:Step:  6660, loss: 0.210, accuracy: 0.94000
# INFO:tensorflow:Step:  6680, loss: 0.111, accuracy: 0.97000
# INFO:tensorflow:Step:  6700, loss: 0.129, accuracy: 0.96000
# INFO:tensorflow:Step:  6720, loss: 0.141, accuracy: 0.95000
# INFO:tensorflow:Step:  6740, loss: 0.155, accuracy: 0.98000
# INFO:tensorflow:Step:  6760, loss: 0.267, accuracy: 0.94000
# INFO:tensorflow:Step:  6780, loss: 0.149, accuracy: 0.94000
# INFO:tensorflow:Step:  6800, loss: 0.090, accuracy: 0.98000
# INFO:tensorflow:Step:  6820, loss: 0.185, accuracy: 0.93000
# INFO:tensorflow:Step:  6840, loss: 0.113, accuracy: 0.98000
# INFO:tensorflow:Step:  6860, loss: 0.148, accuracy: 0.97000
# INFO:tensorflow:Step:  6880, loss: 0.134, accuracy: 0.97000
# INFO:tensorflow:Step:  6900, loss: 0.140, accuracy: 0.96000
# INFO:tensorflow:Step:  6920, loss: 0.063, accuracy: 0.99000
# INFO:tensorflow:Step:  6940, loss: 0.110, accuracy: 0.97000
# INFO:tensorflow:Step:  6960, loss: 0.086, accuracy: 0.97000
# INFO:tensorflow:Step:  6980, loss: 0.081, accuracy: 0.97000
# INFO:tensorflow:Step:  7000, loss: 0.079, accuracy: 0.98000
# INFO:tensorflow:Step:  7020, loss: 0.181, accuracy: 0.93000
# INFO:tensorflow:Step:  7040, loss: 0.192, accuracy: 0.93000
# INFO:tensorflow:Step:  7060, loss: 0.110, accuracy: 0.97000
# INFO:tensorflow:Step:  7080, loss: 0.108, accuracy: 0.97000
# INFO:tensorflow:Step:  7100, loss: 0.091, accuracy: 0.98000
# INFO:tensorflow:Step:  7120, loss: 0.143, accuracy: 0.95000
# INFO:tensorflow:Step:  7140, loss: 0.097, accuracy: 0.96000
# INFO:tensorflow:Step:  7160, loss: 0.070, accuracy: 0.99000
# INFO:tensorflow:Step:  7180, loss: 0.186, accuracy: 0.95000
# INFO:tensorflow:Step:  7200, loss: 0.064, accuracy: 0.98000
# INFO:tensorflow:Step:  7220, loss: 0.069, accuracy: 0.98000
# INFO:tensorflow:Step:  7240, loss: 0.223, accuracy: 0.96000
# INFO:tensorflow:Step:  7260, loss: 0.068, accuracy: 0.98000
# INFO:tensorflow:Step:  7280, loss: 0.184, accuracy: 0.93000
# INFO:tensorflow:Step:  7300, loss: 0.133, accuracy: 0.97000
# INFO:tensorflow:Step:  7320, loss: 0.154, accuracy: 0.95000
# INFO:tensorflow:Step:  7340, loss: 0.059, accuracy: 0.98000
# INFO:tensorflow:Step:  7360, loss: 0.153, accuracy: 0.97000
# INFO:tensorflow:Step:  7380, loss: 0.075, accuracy: 0.99000
# INFO:tensorflow:Step:  7400, loss: 0.082, accuracy: 0.95000
# INFO:tensorflow:Step:  7420, loss: 0.101, accuracy: 0.96000
# INFO:tensorflow:Step:  7440, loss: 0.176, accuracy: 0.94000
# INFO:tensorflow:Step:  7460, loss: 0.090, accuracy: 0.97000
# INFO:tensorflow:Step:  7480, loss: 0.129, accuracy: 0.95000
# INFO:tensorflow:Step:  7500, loss: 0.069, accuracy: 0.98000
# INFO:tensorflow:Step:  7520, loss: 0.108, accuracy: 0.98000
# INFO:tensorflow:Step:  7540, loss: 0.094, accuracy: 0.96000
# INFO:tensorflow:Step:  7560, loss: 0.040, accuracy: 0.99000
# INFO:tensorflow:Step:  7580, loss: 0.067, accuracy: 0.97000
# INFO:tensorflow:Step:  7600, loss: 0.074, accuracy: 0.99000
# INFO:tensorflow:Step:  7620, loss: 0.032, accuracy: 0.99000
# INFO:tensorflow:Step:  7640, loss: 0.165, accuracy: 0.94000
# INFO:tensorflow:Step:  7660, loss: 0.046, accuracy: 0.97000
# INFO:tensorflow:Step:  7680, loss: 0.044, accuracy: 0.98000
# INFO:tensorflow:Step:  7700, loss: 0.080, accuracy: 0.97000
# INFO:tensorflow:Step:  7720, loss: 0.131, accuracy: 0.98000
# INFO:tensorflow:Step:  7740, loss: 0.085, accuracy: 0.99000
# INFO:tensorflow:Step:  7760, loss: 0.078, accuracy: 0.97000
# INFO:tensorflow:Step:  7780, loss: 0.157, accuracy: 0.97000
# INFO:tensorflow:Step:  7800, loss: 0.115, accuracy: 0.96000
# INFO:tensorflow:Step:  7820, loss: 0.017, accuracy: 1.00000
# INFO:tensorflow:Step:  7840, loss: 0.046, accuracy: 0.99000
# INFO:tensorflow:Step:  7860, loss: 0.028, accuracy: 0.99000
# INFO:tensorflow:Step:  7880, loss: 0.159, accuracy: 0.95000
# INFO:tensorflow:Step:  7900, loss: 0.210, accuracy: 0.96000
# INFO:tensorflow:Step:  7920, loss: 0.198, accuracy: 0.94000
# INFO:tensorflow:Step:  7940, loss: 0.094, accuracy: 0.97000
# INFO:tensorflow:Step:  7960, loss: 0.038, accuracy: 0.99000
# INFO:tensorflow:Step:  7980, loss: 0.005, accuracy: 1.00000
# INFO:tensorflow:Step:  8000, loss: 0.071, accuracy: 0.97000
# INFO:tensorflow:Step:  8020, loss: 0.095, accuracy: 0.96000
# INFO:tensorflow:Step:  8040, loss: 0.026, accuracy: 0.99000
# INFO:tensorflow:Step:  8060, loss: 0.018, accuracy: 0.99000
# INFO:tensorflow:Step:  8080, loss: 0.104, accuracy: 0.96000
# INFO:tensorflow:Step:  8100, loss: 0.124, accuracy: 0.97000
# INFO:tensorflow:Step:  8120, loss: 0.188, accuracy: 0.95000
# INFO:tensorflow:Step:  8140, loss: 0.088, accuracy: 0.98000
# INFO:tensorflow:Step:  8160, loss: 0.050, accuracy: 0.98000
# INFO:tensorflow:Step:  8180, loss: 0.022, accuracy: 0.99000
# INFO:tensorflow:Step:  8200, loss: 0.069, accuracy: 0.98000
# INFO:tensorflow:Step:  8220, loss: 0.079, accuracy: 0.96000
# INFO:tensorflow:Step:  8240, loss: 0.016, accuracy: 1.00000
# INFO:tensorflow:Step:  8260, loss: 0.055, accuracy: 0.98000
# INFO:tensorflow:Step:  8280, loss: 0.096, accuracy: 0.97000
# INFO:tensorflow:Step:  8300, loss: 0.098, accuracy: 0.98000
# INFO:tensorflow:Step:  8320, loss: 0.089, accuracy: 0.99000
# INFO:tensorflow:Step:  8340, loss: 0.111, accuracy: 0.95000
# INFO:tensorflow:Step:  8360, loss: 0.039, accuracy: 0.99000
# INFO:tensorflow:Step:  8380, loss: 0.196, accuracy: 0.95000
# INFO:tensorflow:Step:  8400, loss: 0.105, accuracy: 0.95000
# INFO:tensorflow:Step:  8420, loss: 0.081, accuracy: 0.97000
# INFO:tensorflow:Step:  8440, loss: 0.077, accuracy: 0.97000
# INFO:tensorflow:Step:  8460, loss: 0.083, accuracy: 0.97000
# INFO:tensorflow:Step:  8480, loss: 0.134, accuracy: 0.96000
# INFO:tensorflow:Step:  8500, loss: 0.043, accuracy: 1.00000
# INFO:tensorflow:Step:  8520, loss: 0.036, accuracy: 0.98000
# INFO:tensorflow:Step:  8540, loss: 0.019, accuracy: 1.00000
# INFO:tensorflow:Step:  8560, loss: 0.082, accuracy: 0.99000
# INFO:tensorflow:Step:  8580, loss: 0.095, accuracy: 0.98000
# INFO:tensorflow:Step:  8600, loss: 0.107, accuracy: 0.98000
# INFO:tensorflow:Step:  8620, loss: 0.034, accuracy: 1.00000
# INFO:tensorflow:Step:  8640, loss: 0.040, accuracy: 0.98000
# INFO:tensorflow:Step:  8660, loss: 0.073, accuracy: 0.98000
# INFO:tensorflow:Step:  8680, loss: 0.050, accuracy: 0.98000
# INFO:tensorflow:Step:  8700, loss: 0.034, accuracy: 0.98000
# INFO:tensorflow:Step:  8720, loss: 0.035, accuracy: 0.99000
# INFO:tensorflow:Step:  8740, loss: 0.103, accuracy: 0.98000
# INFO:tensorflow:Step:  8760, loss: 0.053, accuracy: 0.99000
# INFO:tensorflow:Step:  8780, loss: 0.071, accuracy: 0.98000
# INFO:tensorflow:Step:  8800, loss: 0.048, accuracy: 0.98000
# INFO:tensorflow:Step:  8820, loss: 0.036, accuracy: 0.99000
# INFO:tensorflow:Step:  8840, loss: 0.181, accuracy: 0.98000
# INFO:tensorflow:Step:  8860, loss: 0.159, accuracy: 0.96000
# INFO:tensorflow:Step:  8880, loss: 0.109, accuracy: 0.97000
# INFO:tensorflow:Step:  8900, loss: 0.184, accuracy: 0.95000
# INFO:tensorflow:Step:  8920, loss: 0.235, accuracy: 0.96000
# INFO:tensorflow:Step:  8940, loss: 0.076, accuracy: 0.97000
# INFO:tensorflow:Step:  8960, loss: 0.051, accuracy: 0.98000
# INFO:tensorflow:Step:  8980, loss: 0.120, accuracy: 0.95000
# INFO:tensorflow:Step:  9000, loss: 0.080, accuracy: 0.98000
# INFO:tensorflow:Step:  9020, loss: 0.127, accuracy: 0.97000
# INFO:tensorflow:Step:  9040, loss: 0.058, accuracy: 0.98000
# INFO:tensorflow:Step:  9060, loss: 0.050, accuracy: 0.98000
# INFO:tensorflow:Step:  9080, loss: 0.027, accuracy: 0.99000
# INFO:tensorflow:Step:  9100, loss: 0.206, accuracy: 0.97000
# INFO:tensorflow:Step:  9120, loss: 0.063, accuracy: 0.97000
# INFO:tensorflow:Step:  9140, loss: 0.052, accuracy: 0.98000
# INFO:tensorflow:Step:  9160, loss: 0.041, accuracy: 0.98000
# INFO:tensorflow:Step:  9180, loss: 0.043, accuracy: 0.99000
# INFO:tensorflow:Step:  9200, loss: 0.005, accuracy: 1.00000
# INFO:tensorflow:Step:  9220, loss: 0.032, accuracy: 1.00000
# INFO:tensorflow:Step:  9240, loss: 0.065, accuracy: 0.98000
# INFO:tensorflow:Step:  9260, loss: 0.145, accuracy: 0.96000
# INFO:tensorflow:Step:  9280, loss: 0.074, accuracy: 0.98000
# INFO:tensorflow:Step:  9300, loss: 0.058, accuracy: 0.98000
# INFO:tensorflow:Step:  9320, loss: 0.125, accuracy: 0.96000
# INFO:tensorflow:Step:  9340, loss: 0.004, accuracy: 1.00000
# INFO:tensorflow:Step:  9360, loss: 0.078, accuracy: 0.99000
# INFO:tensorflow:Step:  9380, loss: 0.022, accuracy: 1.00000
# INFO:tensorflow:Step:  9400, loss: 0.094, accuracy: 0.98000
# INFO:tensorflow:Step:  9420, loss: 0.090, accuracy: 0.98000
# INFO:tensorflow:Step:  9440, loss: 0.056, accuracy: 0.98000
# INFO:tensorflow:Step:  9460, loss: 0.020, accuracy: 0.99000
# INFO:tensorflow:Step:  9480, loss: 0.071, accuracy: 0.97000
# INFO:tensorflow:Step:  9500, loss: 0.050, accuracy: 0.98000
# INFO:tensorflow:Step:  9520, loss: 0.052, accuracy: 0.98000
# INFO:tensorflow:Step:  9540, loss: 0.010, accuracy: 1.00000
# INFO:tensorflow:Step:  9560, loss: 0.101, accuracy: 0.97000
# INFO:tensorflow:Step:  9580, loss: 0.142, accuracy: 0.97000
# INFO:tensorflow:Step:  9600, loss: 0.057, accuracy: 0.98000
# INFO:tensorflow:Step:  9620, loss: 0.017, accuracy: 0.99000
# INFO:tensorflow:Step:  9640, loss: 0.045, accuracy: 0.98000
# INFO:tensorflow:Step:  9660, loss: 0.027, accuracy: 0.98000
# INFO:tensorflow:Step:  9680, loss: 0.033, accuracy: 0.98000
# INFO:tensorflow:Step:  9700, loss: 0.126, accuracy: 0.96000
# INFO:tensorflow:Step:  9720, loss: 0.011, accuracy: 1.00000
# INFO:tensorflow:Step:  9740, loss: 0.128, accuracy: 0.96000
# INFO:tensorflow:Step:  9760, loss: 0.025, accuracy: 0.99000
# INFO:tensorflow:Step:  9780, loss: 0.049, accuracy: 0.98000
# INFO:tensorflow:Step:  9800, loss: 0.048, accuracy: 0.99000
# INFO:tensorflow:Step:  9820, loss: 0.106, accuracy: 0.97000
# INFO:tensorflow:Step:  9840, loss: 0.043, accuracy: 0.99000
# INFO:tensorflow:Step:  9860, loss: 0.046, accuracy: 0.98000
# INFO:tensorflow:Step:  9880, loss: 0.032, accuracy: 0.98000
# INFO:tensorflow:Step:  9900, loss: 0.110, accuracy: 0.97000
# INFO:tensorflow:Step:  9920, loss: 0.148, accuracy: 0.97000
# INFO:tensorflow:Step:  9940, loss: 0.035, accuracy: 0.99000
# INFO:tensorflow:Step:  9960, loss: 0.022, accuracy: 1.00000
# INFO:tensorflow:Step:  9980, loss: 0.086, accuracy: 0.97000
